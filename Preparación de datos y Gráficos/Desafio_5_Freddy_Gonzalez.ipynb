# %% [markdown]
# # Desafío - Preparación de datos y gráficos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/content/world-data-2023.csv')

df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price                GDP  \
# 0            4.47             2.10%         $0.70    $19,101,353,833
# 1            1.62            28.10%         $1.36    $15,278,077,447
# 2            3.02             0.80%         $0.28   $169,988,236,398
# 3            1.27            34.00%         $1.51     $3,154,057,987
# 4            5.52            46.30%         $0.97    $94,635,415,870
#
#   Gross primary education enrollment (%)  \
# 0                                104.00%
# 1                                107.00%
# 2                                109.90%
# 3                                106.40%
# 4                                113.50%
#
#   Gross tertiary education enrollment (%)  Infant mortality      Largest city  \
# 0                                   9.70%              47.9             Kabul
# 1                                  55.00%               7.8            Tirana
# 2                                  51.40%              20.1           Algiers
# 3                                     NaN               2.7  Andorra la Vella
# 4                                   9.30%              51.6            Luanda
#
#    Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 0             64.5                     638.0       $0.43             Pashto
# 1             78.5                      15.0       $1.12           Albanian
# 2             76.7                     112.0       $0.95             Arabic
# 3              NaN                       NaN       $6.63            Catalan
# 4             60.8                     241.0       $0.71         Portuguese
#
#   Out of pocket health expenditure  Physicians per thousand  Population  \
# 0                           78.40%                     0.28  38,041,754
# 1                           56.90%                     1.20   2,854,191
# 2                           28.10%                     1.72  43,053,054
# 3                           36.40%                     3.33      77,142
# 4                           33.40%                     0.21  31,825,295
#
#   Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    55.70%          18.60%         36.60%
# 2                                    41.20%          37.20%         66.10%
# 3                                       NaN             NaN            NaN
# 4                                    77.50%           9.20%         49.10%
#
#   Unemployment rate Urban_population   Latitude  Longitude
# 0            11.12%        9,797,273  33.939110  67.709953
# 1            12.33%        1,747,593  41.153332  20.168331
# 2            11.70%       31,510,100  28.033886   1.659626
# 3               NaN           67,873  42.506285   1.521801
# 4             6.89%       21,061,025 -11.202692  17.873887

# %%
#verificamos el tipo de dato de cada columna y nos damos cuenta que algunas son del tipo object, siendo estas del tipo flotante
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    object
#  4   Land Area(Km2)                             194 non-null    object
#  5   Armed Forces size                          171 non-null    object
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2-Emissions                              188 non-null    object
#  10  CPI                                        178 non-null    object
#  11  CPI Change (%)                             179 non-null    object
#  12  Currency-Code                              180 non-null    object
#  13  Fertility Rate                             188 non-null    float64
#  14  Forested Area (%)                          188 non-null    object
#  15  Gasoline Price                             175 non-null    object
#  16  GDP                                        193 non-null    object
#  17  Gross primary education enrollment (%)     188 non-null    object
#  18  Gross tertiary education enrollment (%)    183 non-null    object
#  19  Infant mortality                           189 non-null    float64
#  20  Largest city                               189 non-null    object
#  21  Life expectancy                            187 non-null    float64
#  22  Maternal mortality ratio                   181 non-null    float64
#  23  Minimum wage                               150 non-null    object
#  24  Official language                          190 non-null    object
#  25  Out of pocket health expenditure           188 non-null    object
#  26  Physicians per thousand                    188 non-null    float64
#  27  Population                                 194 non-null    object
#  28  Population: Labor force participation (%)  176 non-null    object
#  29  Tax revenue (%)                            169 non-null    object
#  30  Total tax rate                             183 non-null    object
#  31  Unemployment rate                          176 non-null    object
#  32  Urban_population                           190 non-null    object
#  33  Latitude                                   194 non-null    float64
#  34  Longitude                                  194 non-null    float64
# dtypes: float64(9), object(26)
# memory usage: 53.4+ KB

# %%
# Función para limpiar columnas numéricas con porcentaje
def clean_percentage(column):
    return column.str.replace('%', '', regex=False).astype(float)

# Función para limpiar columnas monetarias
def clean_currency(column):
    return column.str.replace('[$,]', '', regex=True).astype(float)

# Función para limpiar columnas numéricas con comas
def clean_numeric(column):
    return column.str.replace(',', '', regex=False).astype(float)

# Limpiar columnas específicas
columns_to_clean_percentage = [
    "Agricultural Land( %)", "CPI Change (%)", "Forested Area (%)",
    "Gross primary education enrollment (%)", "Gross tertiary education enrollment (%)",
    "Out of pocket health expenditure", "Population: Labor force participation (%)",
    "Tax revenue (%)", "Total tax rate", "Unemployment rate"
]

columns_to_clean_currency = ["Gasoline Price", "GDP", "Minimum wage"]

columns_to_clean_numeric = ["Land Area(Km2)", "Armed Forces size", "Population", "Urban_population"]

for column in columns_to_clean_percentage:
    df[column] = clean_percentage(df[column])

for column in columns_to_clean_currency:
    df[column] = clean_currency(df[column])

for column in columns_to_clean_numeric:
    df[column] = clean_numeric(df[column])

df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation  Agricultural Land( %)  \
# 0  Afghanistan               60           AF                   58.1
# 1      Albania              105           AL                   43.1
# 2      Algeria               18           DZ                   17.4
# 3      Andorra              164           AD                   40.0
# 4       Angola               26           AO                   47.5
#
#    Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0        652230.0           323000.0       32.49          93.0
# 1         28748.0             9000.0       11.78         355.0
# 2       2381741.0           317000.0       24.28         213.0
# 3           468.0                NaN        7.20         376.0
# 4       1246700.0           117000.0       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI  CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9             2.3           AFN
# 1             Tirana         4,536  119.05             1.4           ALL
# 2            Algiers       150,006  151.36             2.0           DZD
# 3   Andorra la Vella           469     NaN             NaN           EUR
# 4             Luanda        34,693  261.73            17.1           AOA
#
#    Fertility Rate  Forested Area (%)  Gasoline Price           GDP  \
# 0            4.47                2.1            0.70  1.910135e+10
# 1            1.62               28.1            1.36  1.527808e+10
# 2            3.02                0.8            0.28  1.699882e+11
# 3            1.27               34.0            1.51  3.154058e+09
# 4            5.52               46.3            0.97  9.463542e+10
#
#    Gross primary education enrollment (%)  \
# 0                                   104.0
# 1                                   107.0
# 2                                   109.9
# 3                                   106.4
# 4                                   113.5
#
#    Gross tertiary education enrollment (%)  Infant mortality  \
# 0                                      9.7              47.9
# 1                                     55.0               7.8
# 2                                     51.4              20.1
# 3                                      NaN               2.7
# 4                                      9.3              51.6
#
#        Largest city  Life expectancy  Maternal mortality ratio  Minimum wage  \
# 0             Kabul             64.5                     638.0          0.43
# 1            Tirana             78.5                      15.0          1.12
# 2           Algiers             76.7                     112.0          0.95
# 3  Andorra la Vella              NaN                       NaN          6.63
# 4            Luanda             60.8                     241.0          0.71
#
#   Official language  Out of pocket health expenditure  \
# 0            Pashto                              78.4
# 1          Albanian                              56.9
# 2            Arabic                              28.1
# 3           Catalan                              36.4
# 4        Portuguese                              33.4
#
#    Physicians per thousand  Population  \
# 0                     0.28  38041754.0
# 1                     1.20   2854191.0
# 2                     1.72  43053054.0
# 3                     3.33     77142.0
# 4                     0.21  31825295.0
#
#    Population: Labor force participation (%)  Tax revenue (%)  Total tax rate  \
# 0                                       48.9              9.3            71.4
# 1                                       55.7             18.6            36.6
# 2                                       41.2             37.2            66.1
# 3                                        NaN              NaN             NaN
# 4                                       77.5              9.2            49.1
#
#    Unemployment rate  Urban_population   Latitude  Longitude
# 0              11.12         9797273.0  33.939110  67.709953
# 1              12.33         1747593.0  41.153332  20.168331
# 2              11.70        31510100.0  28.033886   1.659626
# 3                NaN           67873.0  42.506285   1.521801
# 4               6.89        21061025.0 -11.202692  17.873887

# %% [markdown]
# 1. Carga los datos y genera un dataFrame que excluya las columnas correspondientes

# %%
# Excluir las columnas especificadas
columns_to_exclude = ['Abbreviation', 'Calling Code', 'capital',
                      'Currency-Code', 'Largest city', 'Official language',
                      'Latitude', 'Longitude']
df_filtrado = df.drop(columns=columns_to_exclude, errors='ignore')
df_filtrado.head()
# Out:
#        Country Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# 0  Afghanistan               60                   58.1        652230.0
# 1      Albania              105                   43.1         28748.0
# 2      Algeria               18                   17.4       2381741.0
# 3      Andorra              164                   40.0           468.0
# 4       Angola               26                   47.5       1246700.0
#
#    Armed Forces size  Birth Rate Capital/Major City Co2-Emissions     CPI  \
# 0           323000.0       32.49              Kabul         8,672   149.9
# 1             9000.0       11.78             Tirana         4,536  119.05
# 2           317000.0       24.28            Algiers       150,006  151.36
# 3                NaN        7.20   Andorra la Vella           469     NaN
# 4           117000.0       40.73             Luanda        34,693  261.73
#
#    CPI Change (%)  Fertility Rate  Forested Area (%)  Gasoline Price  \
# 0             2.3            4.47                2.1            0.70
# 1             1.4            1.62               28.1            1.36
# 2             2.0            3.02                0.8            0.28
# 3             NaN            1.27               34.0            1.51
# 4            17.1            5.52               46.3            0.97
#
#             GDP  Gross primary education enrollment (%)  \
# 0  1.910135e+10                                   104.0
# 1  1.527808e+10                                   107.0
# 2  1.699882e+11                                   109.9
# 3  3.154058e+09                                   106.4
# 4  9.463542e+10                                   113.5
#
#    Gross tertiary education enrollment (%)  Infant mortality  Life expectancy  \
# 0                                      9.7              47.9             64.5
# 1                                     55.0               7.8             78.5
# 2                                     51.4              20.1             76.7
# 3                                      NaN               2.7              NaN
# 4                                      9.3              51.6             60.8
#
#    Maternal mortality ratio  Minimum wage  Out of pocket health expenditure  \
# 0                     638.0          0.43                              78.4
# 1                      15.0          1.12                              56.9
# 2                     112.0          0.95                              28.1
# 3                       NaN          6.63                              36.4
# 4                     241.0          0.71                              33.4
#
#    Physicians per thousand  Population  \
# 0                     0.28  38041754.0
# 1                     1.20   2854191.0
# 2                     1.72  43053054.0
# 3                     3.33     77142.0
# 4                     0.21  31825295.0
#
#    Population: Labor force participation (%)  Tax revenue (%)  Total tax rate  \
# 0                                       48.9              9.3            71.4
# 1                                       55.7             18.6            36.6
# 2                                       41.2             37.2            66.1
# 3                                        NaN              NaN             NaN
# 4                                       77.5              9.2            49.1
#
#    Unemployment rate  Urban_population
# 0              11.12         9797273.0
# 1              12.33         1747593.0
# 2              11.70        31510100.0
# 3                NaN           67873.0
# 4               6.89        21061025.0

# %%
# Inspección inicial
print("\nInformación del dataframe filtrado:")
print(df_filtrado.info())
print("\nEstadísticas descriptivas:")
print(df_filtrado.describe())
# Out:
# Información del dataframe filtrado:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Agricultural Land( %)                      188 non-null    float64
#  3   Land Area(Km2)                             194 non-null    float64
#  4   Armed Forces size                          171 non-null    float64
#  5   Birth Rate                                 189 non-null    float64
#  6   Capital/Major City                         192 non-null    object
#  7   Co2-Emissions                              188 non-null    object
#  8   CPI                                        178 non-null    object
#  9   CPI Change (%)                             179 non-null    float64
#  10  Fertility Rate                             188 non-null    float64
#  11  Forested Area (%)                          188 non-null    float64
#  12  Gasoline Price                             175 non-null    float64
#  13  GDP                                        193 non-null    float64
#  14  Gross primary education enrollment (%)     188 non-null    float64
#  15  Gross tertiary education enrollment (%)    183 non-null    float64
#  16  Infant mortality                           189 non-null    float64
#  17  Life expectancy                            187 non-null    float64
#  18  Maternal mortality ratio                   181 non-null    float64
#  19  Minimum wage                               150 non-null    float64
#  20  Out of pocket health expenditure           188 non-null    float64
#  21  Physicians per thousand                    188 non-null    float64
#  22  Population                                 194 non-null    float64
#  23  Population: Labor force participation (%)  176 non-null    float64
#  24  Tax revenue (%)                            169 non-null    float64
#  25  Total tax rate                             183 non-null    float64
#  26  Unemployment rate                          176 non-null    float64
#  27  Urban_population                           190 non-null    float64
# dtypes: float64(23), object(5)
# memory usage: 42.8+ KB
# None
#
# Estadísticas descriptivas:
#        Agricultural Land( %)  Land Area(Km2)  Armed Forces size  Birth Rate  \
# count             188.000000    1.940000e+02       1.710000e+02  189.000000
# mean               39.117553    6.896244e+05       1.592749e+05   20.214974
# std                21.783052    1.921609e+06       3.806288e+05    9.945774
# min                 0.600000    0.000000e+00       0.000000e+00    5.900000
# 25%                21.700000    2.382825e+04       1.100000e+04   11.300000
# 50%                39.600000    1.195110e+05       3.100000e+04   17.950000
# 75%                55.375000    5.242560e+05       1.420000e+05   28.750000
# max                82.600000    1.709824e+07       3.031000e+06   46.080000
#
#        CPI Change (%)  Fertility Rate  Forested Area (%)  Gasoline Price  \
# count      179.000000      188.000000         188.000000      175.000000
# mean         6.722346        2.698138          32.015426        1.002457
# std         24.450414        1.282267          23.791331        0.368858
# min         -4.300000        0.980000           0.000000        0.000000
# 25%          1.000000        1.705000          11.000000        0.755000
# 50%          2.300000        2.245000          32.000000        0.980000
# 75%          4.250000        3.597500          48.175000        1.240000
# max        254.900000        6.910000          98.300000        2.000000
#
#                 GDP  Gross primary education enrollment (%)  \
# count  1.930000e+02                              188.000000
# mean   4.772959e+11                              102.470213
# std    2.172173e+12                               13.151607
# min    4.727146e+07                               23.400000
# 25%    8.454620e+09                               98.950000
# 50%    3.438723e+10                              102.550000
# 75%    2.340940e+11                              108.025000
# max    2.142770e+13                              142.500000
#
#        Gross tertiary education enrollment (%)  Infant mortality  \
# count                               183.000000        189.000000
# mean                                 37.963388         21.332804
# std                                  29.261022         19.548058
# min                                   0.800000          1.400000
# 25%                                  12.150000          6.000000
# 50%                                  31.200000         14.000000
# 75%                                  63.150000         32.700000
# max                                 136.600000         84.500000
#
#        Life expectancy  Maternal mortality ratio  Minimum wage  \
# count       187.000000                181.000000    150.000000
# mean         72.279679                160.392265      2.194133
# std           7.483661                233.502024      2.970796
# min          52.800000                  2.000000      0.010000
# 25%          67.000000                 13.000000      0.402500
# 50%          73.200000                 53.000000      1.045000
# 75%          77.500000                186.000000      2.447500
# max          85.400000               1150.000000     13.590000
#
#        Out of pocket health expenditure  Physicians per thousand  \
# count                        188.000000               188.000000
# mean                          32.637234                 1.839840
# std                           19.172697                 1.684261
# min                            0.200000                 0.010000
# 25%                           17.450000                 0.332500
# 50%                           30.700000                 1.460000
# 75%                           43.975000                 2.935000
# max                           81.600000                 8.420000
#
#          Population  Population: Labor force participation (%)  \
# count  1.940000e+02                                 176.000000
# mean   3.938116e+07                                  62.738068
# std    1.450924e+08                                  10.502907
# min    8.360000e+02                                  38.000000
# 25%    1.962678e+06                                  56.150000
# 50%    8.826588e+06                                  62.450000
# 75%    2.858549e+07                                  69.500000
# max    1.397715e+09                                  86.800000
#
#        Tax revenue (%)  Total tax rate  Unemployment rate  Urban_population
# count       169.000000      183.000000         176.000000      1.900000e+02
# mean         16.573964       40.822404           6.886364      2.230454e+07
# std           6.961632       20.557662           5.079216      7.543050e+07
# min           0.000000        8.000000           0.090000      5.464000e+03
# 25%          11.700000       30.600000           3.395000      1.152961e+06
# 50%          16.300000       37.200000           5.360000      4.678104e+06
# 75%          21.100000       48.000000           9.490000      1.490324e+07
# max          37.200000      219.600000          28.180000      8.429340e+08

# %%
# Visualización gráfica
# Histograma para analizar la distribución de una columna numérica (ejemplo: Población)

plt.figure(figsize=(10, 6))
sns.histplot(df_filtrado['Population'], bins=30, kde=True)
plt.title('Distribución de la Población')
plt.xlabel('Población')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# 2. De las variables codificadas numéricamente, ¿hay pares de ellas en la que parezca
# haber correlación? ¿Para cuál(es) de ellas se observa más claramente?

# %%
# Filtrar solo las columnas numéricas
numerical_columns = df_filtrado.select_dtypes(include=['number'])

# Calcular la matriz de correlación
correlation_matrix = numerical_columns.corr()

# Mostrar la matriz de correlación
print("\nMatriz de correlación:")
print(correlation_matrix)

# Visualizar la matriz de correlación con un mapa de calor
plt.figure(figsize=(30, 30))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Mapa de calor de la correlación entre variables numéricas')
plt.show()
# Out:
# Matriz de correlación:
#                                            Agricultural Land( %)  \
# Agricultural Land( %)                                   1.000000
# Land Area(Km2)                                         -0.031189
# Armed Forces size                                       0.030547
# Birth Rate                                              0.199269
# CPI Change (%)                                         -0.010878
# Fertility Rate                                          0.180507
# Forested Area (%)                                      -0.434570
# Gasoline Price                                          0.047724
# GDP                                                     0.051840
# Gross primary education enrollment (%)                 -0.047046
# Gross tertiary education enrollment (%)                -0.111015
# Infant mortality                                        0.207010
# Life expectancy                                        -0.243771
# Maternal mortality ratio                                0.213170
# Minimum wage                                           -0.026780
# Out of pocket health expenditure                        0.135180
# Physicians per thousand                                -0.036503
# Population                                              0.117506
# Population: Labor force participation (%)              -0.112016
# Tax revenue (%)                                        -0.056104
# Total tax rate                                          0.167139
# Unemployment rate                                       0.062049
# Urban_population                                        0.101679
#
#                                            Land Area(Km2)  Armed Forces size  \
# Agricultural Land( %)                           -0.031189           0.030547
# Land Area(Km2)                                   1.000000           0.551730
# Armed Forces size                                0.551730           1.000000
# Birth Rate                                      -0.066269          -0.144801
# CPI Change (%)                                   0.034210           0.061519
# Fertility Rate                                  -0.064764          -0.146258
# Forested Area (%)                               -0.014278          -0.019928
# Gasoline Price                                  -0.186857          -0.154579
# GDP                                              0.550592           0.605486
# Gross primary education enrollment (%)           0.006122           0.057974
# Gross tertiary education enrollment (%)          0.220470           0.110247
# Infant mortality                                -0.066310          -0.077283
# Life expectancy                                  0.054921           0.075943
# Maternal mortality ratio                        -0.054190          -0.104969
# Minimum wage                                     0.118949          -0.020528
# Out of pocket health expenditure                -0.013867           0.154367
# Physicians per thousand                          0.072006           0.013848
# Population                                       0.446721           0.875912
# Population: Labor force participation (%)       -0.007052          -0.082975
# Tax revenue (%)                                 -0.168567          -0.182969
# Total tax rate                                   0.089932           0.158674
# Unemployment rate                                0.042922          -0.025011
# Urban_population                                 0.546836           0.851101
#
#                                            Birth Rate  CPI Change (%)  \
# Agricultural Land( %)                        0.199269       -0.010878
# Land Area(Km2)                              -0.066269        0.034210
# Armed Forces size                           -0.144801        0.061519
# Birth Rate                                   1.000000        0.107160
# CPI Change (%)                               0.107160        1.000000
# Fertility Rate                               0.981069        0.097405
# Forested Area (%)                           -0.074321        0.015317
# Gasoline Price                              -0.204322       -0.275388
# GDP                                         -0.181216       -0.011083
# Gross primary education enrollment (%)      -0.083156       -0.158228
# Gross tertiary education enrollment (%)     -0.728755        0.065089
# Infant mortality                             0.867456        0.158888
# Life expectancy                             -0.874747       -0.150087
# Maternal mortality ratio                     0.768078        0.227810
# Minimum wage                                -0.503070       -0.104414
# Out of pocket health expenditure             0.256198        0.136583
# Physicians per thousand                     -0.740290       -0.040019
# Population                                  -0.053263        0.005618
# Population: Labor force participation (%)    0.171302       -0.016332
# Tax revenue (%)                             -0.375103       -0.241255
# Total tax rate                               0.199608        0.117012
# Unemployment rate                           -0.043458        0.111920
# Urban_population                            -0.107609        0.007353
#
#                                            Fertility Rate  Forested Area (%)  \
# Agricultural Land( %)                            0.180507          -0.434570
# Land Area(Km2)                                  -0.064764          -0.014278
# Armed Forces size                               -0.146258          -0.019928
# Birth Rate                                       0.981069          -0.074321
# CPI Change (%)                                   0.097405           0.015317
# Fertility Rate                                   1.000000          -0.063429
# Forested Area (%)                               -0.063429           1.000000
# Gasoline Price                                  -0.126090           0.145923
# GDP                                             -0.160240          -0.000565
# Gross primary education enrollment (%)          -0.142988           0.144674
# Gross tertiary education enrollment (%)         -0.684777          -0.010183
# Infant mortality                                 0.852653          -0.055932
# Life expectancy                                 -0.849153           0.005900
# Maternal mortality ratio                         0.779460          -0.066012
# Minimum wage                                    -0.431950          -0.033010
# Out of pocket health expenditure                 0.204644          -0.245361
# Physicians per thousand                         -0.683172          -0.083118
# Population                                      -0.055491          -0.055625
# Population: Labor force participation (%)        0.156793           0.153807
# Tax revenue (%)                                 -0.373152           0.122597
# Total tax rate                                   0.210859           0.033275
# Unemployment rate                               -0.072601          -0.083790
# Urban_population                                -0.104058          -0.034797
#
#                                            Gasoline Price       GDP  \
# Agricultural Land( %)                            0.047724  0.051840
# Land Area(Km2)                                  -0.186857  0.550592
# Armed Forces size                               -0.154579  0.605486
# Birth Rate                                      -0.204322 -0.181216
# CPI Change (%)                                  -0.275388 -0.011083
# Fertility Rate                                  -0.126090 -0.160240
# Forested Area (%)                                0.145923 -0.000565
# Gasoline Price                                   1.000000 -0.019822
# GDP                                             -0.019822  1.000000
# Gross primary education enrollment (%)          -0.074015 -0.004062
# Gross tertiary education enrollment (%)          0.159178  0.211881
# Infant mortality                                -0.164480 -0.152934
# Life expectancy                                  0.247971  0.175755
# Maternal mortality ratio                        -0.070771 -0.121590
# Minimum wage                                     0.436155  0.208190
# Out of pocket health expenditure                -0.294134 -0.099626
# Physicians per thousand                          0.260714  0.091867
# Population                                      -0.071593  0.632326
# Population: Labor force participation (%)       -0.011114 -0.007028
# Tax revenue (%)                                  0.424858 -0.118468
# Total tax rate                                   0.072264  0.051237
# Unemployment rate                               -0.042275  0.031221
# Urban_population                                -0.074689  0.784276
#
#                                            Gross primary education enrollment (%)  \
# Agricultural Land( %)                                                   -0.047046
# Land Area(Km2)                                                           0.006122
# Armed Forces size                                                        0.057974
# Birth Rate                                                              -0.083156
# CPI Change (%)                                                          -0.158228
# Fertility Rate                                                          -0.142988
# Forested Area (%)                                                        0.144674
# Gasoline Price                                                          -0.074015
# GDP                                                                     -0.004062
# Gross primary education enrollment (%)                                   1.000000
# Gross tertiary education enrollment (%)                                 -0.009141
# Infant mortality                                                        -0.140598
# Life expectancy                                                          0.094907
# Maternal mortality ratio                                                -0.173013
# Minimum wage                                                            -0.065615
# Out of pocket health expenditure                                        -0.177153
# Physicians per thousand                                                 -0.026378
# Population                                                               0.039608
# Population: Labor force participation (%)                                0.224648
# Tax revenue (%)                                                          0.169776
# Total tax rate                                                          -0.070307
# Unemployment rate                                                       -0.034664
# Urban_population                                                         0.028690
#
#                                            Gross tertiary education enrollment (%)  \
# Agricultural Land( %)                                                    -0.111015
# Land Area(Km2)                                                            0.220470
# Armed Forces size                                                         0.110247
# Birth Rate                                                               -0.728755
# CPI Change (%)                                                            0.065089
# Fertility Rate                                                           -0.684777
# Forested Area (%)                                                        -0.010183
# Gasoline Price                                                            0.159178
# GDP                                                                       0.211881
# Gross primary education enrollment (%)                                   -0.009141
# Gross tertiary education enrollment (%)                                   1.000000
# Infant mortality                                                         -0.715064
# Life expectancy                                                           0.722535
# Maternal mortality ratio                                                 -0.599951
# Minimum wage                                                              0.543074
# Out of pocket health expenditure                                         -0.175981
# Physicians per thousand                                                   0.717081
# Population                                                                0.025119
# Population: Labor force participation (%)                                -0.161140
# Tax revenue (%)                                                           0.289492
# Total tax rate                                                           -0.032745
# Unemployment rate                                                         0.038432
# Urban_population                                                          0.097051
#
#                                            Infant mortality  Life expectancy  \
# Agricultural Land( %)                              0.207010        -0.243771
# Land Area(Km2)                                    -0.066310         0.054921
# Armed Forces size                                 -0.077283         0.075943
# Birth Rate                                         0.867456        -0.874747
# CPI Change (%)                                     0.158888        -0.150087
# Fertility Rate                                     0.852653        -0.849153
# Forested Area (%)                                 -0.055932         0.005900
# Gasoline Price                                    -0.164480         0.247971
# GDP                                               -0.152934         0.175755
# Gross primary education enrollment (%)            -0.140598         0.094907
# Gross tertiary education enrollment (%)           -0.715064         0.722535
# Infant mortality                                   1.000000        -0.924675
# Life expectancy                                   -0.924675         1.000000
# Maternal mortality ratio                           0.874135        -0.831797
# Minimum wage                                      -0.482233         0.599969
# Out of pocket health expenditure                   0.351509        -0.326162
# Physicians per thousand                           -0.691382         0.703740
# Population                                         0.004678         0.008816
# Population: Labor force participation (%)          0.124945        -0.154818
# Tax revenue (%)                                   -0.393403         0.363980
# Total tax rate                                     0.237384        -0.188535
# Unemployment rate                                  0.001766        -0.040152
# Urban_population                                  -0.057372         0.070463
#
#                                            Maternal mortality ratio  \
# Agricultural Land( %)                                      0.213170
# Land Area(Km2)                                            -0.054190
# Armed Forces size                                         -0.104969
# Birth Rate                                                 0.768078
# CPI Change (%)                                             0.227810
# Fertility Rate                                             0.779460
# Forested Area (%)                                         -0.066012
# Gasoline Price                                            -0.070771
# GDP                                                       -0.121590
# Gross primary education enrollment (%)                    -0.173013
# Gross tertiary education enrollment (%)                   -0.599951
# Infant mortality                                           0.874135
# Life expectancy                                           -0.831797
# Maternal mortality ratio                                   1.000000
# Minimum wage                                              -0.357888
# Out of pocket health expenditure                           0.281283
# Physicians per thousand                                   -0.582919
# Population                                                -0.023810
# Population: Labor force participation (%)                  0.187440
# Tax revenue (%)                                           -0.383712
# Total tax rate                                             0.208176
# Unemployment rate                                         -0.036689
# Urban_population                                          -0.067213
#
#                                            Minimum wage  \
# Agricultural Land( %)                         -0.026780
# Land Area(Km2)                                 0.118949
# Armed Forces size                             -0.020528
# Birth Rate                                    -0.503070
# CPI Change (%)                                -0.104414
# Fertility Rate                                -0.431950
# Forested Area (%)                             -0.033010
# Gasoline Price                                 0.436155
# GDP                                            0.208190
# Gross primary education enrollment (%)        -0.065615
# Gross tertiary education enrollment (%)        0.543074
# Infant mortality                              -0.482233
# Life expectancy                                0.599969
# Maternal mortality ratio                      -0.357888
# Minimum wage                                   1.000000
# Out of pocket health expenditure              -0.433513
# Physicians per thousand                        0.470934
# Population                                    -0.047272
# Population: Labor force participation (%)     -0.059727
# Tax revenue (%)                                0.297308
# Total tax rate                                -0.068973
# Unemployment rate                             -0.055904
# Urban_population                               0.008586
#
#                                            Out of pocket health expenditure  \
# Agricultural Land( %)                                              0.135180
# Land Area(Km2)                                                    -0.013867
# Armed Forces size                                                  0.154367
# Birth Rate                                                         0.256198
# CPI Change (%)                                                     0.136583
# Fertility Rate                                                     0.204644
# Forested Area (%)                                                 -0.245361
# Gasoline Price                                                    -0.294134
# GDP                                                               -0.099626
# Gross primary education enrollment (%)                            -0.177153
# Gross tertiary education enrollment (%)                           -0.175981
# Infant mortality                                                   0.351509
# Life expectancy                                                   -0.326162
# Maternal mortality ratio                                           0.281283
# Minimum wage                                                      -0.433513
# Out of pocket health expenditure                                   1.000000
# Physicians per thousand                                           -0.186712
# Population                                                         0.131728
# Population: Labor force participation (%)                         -0.203872
# Tax revenue (%)                                                   -0.354792
# Total tax rate                                                     0.251254
# Unemployment rate                                                  0.027946
# Urban_population                                                   0.064660
#
#                                            Physicians per thousand  \
# Agricultural Land( %)                                    -0.036503
# Land Area(Km2)                                            0.072006
# Armed Forces size                                         0.013848
# Birth Rate                                               -0.740290
# CPI Change (%)                                           -0.040019
# Fertility Rate                                           -0.683172
# Forested Area (%)                                        -0.083118
# Gasoline Price                                            0.260714
# GDP                                                       0.091867
# Gross primary education enrollment (%)                   -0.026378
# Gross tertiary education enrollment (%)                   0.717081
# Infant mortality                                         -0.691382
# Life expectancy                                           0.703740
# Maternal mortality ratio                                 -0.582919
# Minimum wage                                              0.470934
# Out of pocket health expenditure                         -0.186712
# Physicians per thousand                                   1.000000
# Population                                               -0.049307
# Population: Labor force participation (%)                -0.152604
# Tax revenue (%)                                           0.293689
# Total tax rate                                           -0.108104
# Unemployment rate                                         0.002295
# Urban_population                                          0.000463
#
#                                            Population  \
# Agricultural Land( %)                        0.117506
# Land Area(Km2)                               0.446721
# Armed Forces size                            0.875912
# Birth Rate                                  -0.053263
# CPI Change (%)                               0.005618
# Fertility Rate                              -0.055491
# Forested Area (%)                           -0.055625
# Gasoline Price                              -0.071593
# GDP                                          0.632326
# Gross primary education enrollment (%)       0.039608
# Gross tertiary education enrollment (%)      0.025119
# Infant mortality                             0.004678
# Life expectancy                              0.008816
# Maternal mortality ratio                    -0.023810
# Minimum wage                                -0.047272
# Out of pocket health expenditure             0.131728
# Physicians per thousand                     -0.049307
# Population                                   1.000000
# Population: Labor force participation (%)   -0.057189
# Tax revenue (%)                             -0.190038
# Total tax rate                               0.082072
# Unemployment rate                           -0.042290
# Urban_population                             0.954204
#
#                                            Population: Labor force participation (%)  \
# Agricultural Land( %)                                                      -0.112016
# Land Area(Km2)                                                             -0.007052
# Armed Forces size                                                          -0.082975
# Birth Rate                                                                  0.171302
# CPI Change (%)                                                             -0.016332
# Fertility Rate                                                              0.156793
# Forested Area (%)                                                           0.153807
# Gasoline Price                                                             -0.011114
# GDP                                                                        -0.007028
# Gross primary education enrollment (%)                                      0.224648
# Gross tertiary education enrollment (%)                                    -0.161140
# Infant mortality                                                            0.124945
# Life expectancy                                                            -0.154818
# Maternal mortality ratio                                                    0.187440
# Minimum wage                                                               -0.059727
# Out of pocket health expenditure                                           -0.203872
# Physicians per thousand                                                    -0.152604
# Population                                                                 -0.057189
# Population: Labor force participation (%)                                   1.000000
# Tax revenue (%)                                                            -0.121457
# Total tax rate                                                             -0.174230
# Unemployment rate                                                          -0.434142
# Urban_population                                                           -0.048768
#
#                                            Tax revenue (%)  Total tax rate  \
# Agricultural Land( %)                            -0.056104        0.167139
# Land Area(Km2)                                   -0.168567        0.089932
# Armed Forces size                                -0.182969        0.158674
# Birth Rate                                       -0.375103        0.199608
# CPI Change (%)                                   -0.241255        0.117012
# Fertility Rate                                   -0.373152        0.210859
# Forested Area (%)                                 0.122597        0.033275
# Gasoline Price                                    0.424858        0.072264
# GDP                                              -0.118468        0.051237
# Gross primary education enrollment (%)            0.169776       -0.070307
# Gross tertiary education enrollment (%)           0.289492       -0.032745
# Infant mortality                                 -0.393403        0.237384
# Life expectancy                                   0.363980       -0.188535
# Maternal mortality ratio                         -0.383712        0.208176
# Minimum wage                                      0.297308       -0.068973
# Out of pocket health expenditure                 -0.354792        0.251254
# Physicians per thousand                           0.293689       -0.108104
# Population                                       -0.190038        0.082072
# Population: Labor force participation (%)        -0.121457       -0.174230
# Tax revenue (%)                                   1.000000       -0.117003
# Total tax rate                                   -0.117003        1.000000
# Unemployment rate                                 0.225804       -0.034378
# Urban_population                                 -0.184573        0.098645
#
#                                            Unemployment rate  Urban_population
# Agricultural Land( %)                               0.062049          0.101679
# Land Area(Km2)                                      0.042922          0.546836
# Armed Forces size                                  -0.025011          0.851101
# Birth Rate                                         -0.043458         -0.107609
# CPI Change (%)                                      0.111920          0.007353
# Fertility Rate                                     -0.072601         -0.104058
# Forested Area (%)                                  -0.083790         -0.034797
# Gasoline Price                                     -0.042275         -0.074689
# GDP                                                 0.031221          0.784276
# Gross primary education enrollment (%)             -0.034664          0.028690
# Gross tertiary education enrollment (%)             0.038432          0.097051
# Infant mortality                                    0.001766         -0.057372
# Life expectancy                                    -0.040152          0.070463
# Maternal mortality ratio                           -0.036689         -0.067213
# Minimum wage                                       -0.055904          0.008586
# Out of pocket health expenditure                    0.027946          0.064660
# Physicians per thousand                             0.002295          0.000463
# Population                                         -0.042290          0.954204
# Population: Labor force participation (%)          -0.434142         -0.048768
# Tax revenue (%)                                     0.225804         -0.184573
# Total tax rate                                     -0.034378          0.098645
# Unemployment rate                                   1.000000         -0.014622
# Urban_population                                   -0.014622          1.000000

# %% [markdown]
# para analizar este resultado debemos tomar en cuenta que si la correlación entre dos variables tiene un valor cercano a +1 o -1, indica una relación lineal fuerte.
# Los valores cercanos a +1 muestran una correlación positiva, mientras que los cercanos a -1 indican una correlación negativa. En nuestro caso las correlaciones mas fuertes son entre mortalidad infantil y la tasa de natalidad, tambien mortalidad infantil con tasa defertilidad, del mismo modo expectativa de vida esta relacionada con tasa de natalidad y tasa de fertilidad, pero las relaciónes mas fuertes observadas fueron la tasa de mortalidad materna y expectativa de vida con un 0,87 y la de expectativa de vida y la de mortalidad infantil con un 0,92. En el siguiente gráfico se puede observas mas claramente.

# %%
sns.scatterplot(data=df, x='Maternal mortality ratio', y='Life expectancy')
# Out:
# <Axes: xlabel='Maternal mortality ratio', ylabel='Life expectancy'>

# %%
sns.scatterplot(data=df, x='Infant mortality', y='Life expectancy')
# Out:
# <Axes: xlabel='Infant mortality', ylabel='Life expectancy'>

# %% [markdown]
# 3. Considera los dos pares de variables anteriores y elimina en cada caso los faltantes
# y atípicos. Justifica en cada caso tu procedimiento.

# %%
df_filtrado.head()
# Out:
#        Country Density\n(P/Km2)  Agricultural Land( %)  Land Area(Km2)  \
# 0  Afghanistan               60                   58.1        652230.0
# 1      Albania              105                   43.1         28748.0
# 2      Algeria               18                   17.4       2381741.0
# 3      Andorra              164                   40.0           468.0
# 4       Angola               26                   47.5       1246700.0
#
#    Armed Forces size  Birth Rate Capital/Major City Co2-Emissions     CPI  \
# 0           323000.0       32.49              Kabul         8,672   149.9
# 1             9000.0       11.78             Tirana         4,536  119.05
# 2           317000.0       24.28            Algiers       150,006  151.36
# 3                NaN        7.20   Andorra la Vella           469     NaN
# 4           117000.0       40.73             Luanda        34,693  261.73
#
#    CPI Change (%)  Fertility Rate  Forested Area (%)  Gasoline Price  \
# 0             2.3            4.47                2.1            0.70
# 1             1.4            1.62               28.1            1.36
# 2             2.0            3.02                0.8            0.28
# 3             NaN            1.27               34.0            1.51
# 4            17.1            5.52               46.3            0.97
#
#             GDP  Gross primary education enrollment (%)  \
# 0  1.910135e+10                                   104.0
# 1  1.527808e+10                                   107.0
# 2  1.699882e+11                                   109.9
# 3  3.154058e+09                                   106.4
# 4  9.463542e+10                                   113.5
#
#    Gross tertiary education enrollment (%)  Infant mortality  Life expectancy  \
# 0                                      9.7              47.9             64.5
# 1                                     55.0               7.8             78.5
# 2                                     51.4              20.1             76.7
# 3                                      NaN               2.7              NaN
# 4                                      9.3              51.6             60.8
#
#    Maternal mortality ratio  Minimum wage  Out of pocket health expenditure  \
# 0                     638.0          0.43                              78.4
# 1                      15.0          1.12                              56.9
# 2                     112.0          0.95                              28.1
# 3                       NaN          6.63                              36.4
# 4                     241.0          0.71                              33.4
#
#    Physicians per thousand  Population  \
# 0                     0.28  38041754.0
# 1                     1.20   2854191.0
# 2                     1.72  43053054.0
# 3                     3.33     77142.0
# 4                     0.21  31825295.0
#
#    Population: Labor force participation (%)  Tax revenue (%)  Total tax rate  \
# 0                                       48.9              9.3            71.4
# 1                                       55.7             18.6            36.6
# 2                                       41.2             37.2            66.1
# 3                                        NaN              NaN             NaN
# 4                                       77.5              9.2            49.1
#
#    Unemployment rate  Urban_population
# 0              11.12         9797273.0
# 1              12.33         1747593.0
# 2              11.70        31510100.0
# 3                NaN           67873.0
# 4               6.89        21061025.0

# %%
#  Eliminar valores faltantes y atípicos
# 1er par de variables: 'Tasa de mortalidad materna' y 'Expectativa de vida'
variables_par1 = ['Maternal mortality ratio', 'Life expectancy']
df_par1 = df_filtrado[variables_par1].dropna()  # Eliminar filas con valores faltantes

# Eliminar outliers usando el rango intercuartílico (IQR)
Q1_par1 = df_par1.quantile(0.25)
Q3_par1 = df_par1.quantile(0.75)
IQR_par1 = Q3_par1 - Q1_par1
df_par1_cleaned = df_par1[~((df_par1 < (Q1_par1 - 1.5 * IQR_par1)) | (df_par1 > (Q3_par1 + 1.5 * IQR_par1))).any(axis=1)]
print("\nDatos del primer par después de limpiar faltantes y atípicos:")
print(df_par1_cleaned.describe())
# Out:
# Datos del primer par después de limpiar faltantes y atípicos:
#        Maternal mortality ratio  Life expectancy
# count                158.000000       158.000000
# mean                  84.917722        74.009494
# std                  103.288352         5.949231
# min                    2.000000        58.400000
# 25%                   10.000000        70.500000
# 50%                   38.000000        74.450000
# 75%                  120.750000        78.175000
# max                  401.000000        84.200000

# %%
# 2do par de variables: Expectativa de vida y Mortalidad Infantil
variables_par2 = ['Life expectancy', 'Infant mortality']
df_par2 = df_filtrado[variables_par2].dropna()  # Eliminar filas con valores faltantes

# Eliminar outliers usando el rango intercuartílico (IQR)
Q1_par2 = df_par2.quantile(0.25)
Q3_par2 = df_par2.quantile(0.75)
IQR_par2 = Q3_par2 - Q1_par2
df_par2_cleaned = df_par2[~((df_par2 < (Q1_par2 - 1.5 * IQR_par2)) | (df_par2 > (Q3_par2 + 1.5 * IQR_par2))).any(axis=1)]

print("\nDatos del segundo par después de limpiar faltantes y atípicos:")
print(df_par2_cleaned.describe())
# Out:
# Datos del segundo par después de limpiar faltantes y atípicos:
#        Life expectancy  Infant mortality
# count       182.000000        182.000000
# mean         72.608791         20.278571
# std           7.061649         17.849965
# min          53.700000          1.400000
# 25%          67.625000          6.025000
# 50%          73.500000         13.800000
# 75%          77.550000         31.125000
# max          85.400000         71.400000

# %% [markdown]
# Se eliminan las filas con valores faltantes para garantizar que los cálculos de correlación y análisis posteriores no sean afectados por datos incompletos.
# En caso de que una columna tenga una alta cantidad de valores faltantes, se podría considerar imputarlos (p. ej., con la mediana).
# Los atípicos se identifican utilizando el rango intercuartílico (IQR), un método robusto y ampliamente usado que no se ve influenciado por valores extremos.
# Los valores fuera del rango [Q1−1.5⋅IQR,Q3+1.5⋅IQR] se eliminan, ya que pueden distorsionar el análisis de correlación.

# %% [markdown]
# 4. Construye un gráfico para verificar la correlación entre estas variables, ahora con los
# datos preparados. Compara con lo obtenido anteriormente.

# %%
# 1er par: Tasa de Mortalidad Materna vs Espectativa de vida
plt.subplot(1, 2, 1)
sns.scatterplot(data=df_par1_cleaned, x='Maternal mortality ratio', y='Life expectancy', alpha=0.6, color='orange')
plt.title('Tasa de Mortalidad Materna vs Expectativa de Vida (Después de la limpieza)')
plt.xlabel('Maternal mortality ratio')
plt.ylabel('Life expectancy')
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
correlation_par1_after = df_par1_cleaned.corr().iloc[0, 1]
print(f"Correlación entre 'Maternal mortality ratio' y 'Life expectancy' después de la limpieza: {correlation_par1_after}")
# Out:
# Correlación entre 'Maternal mortality ratio' y 'Life expectancy' después de la limpieza: -0.8138596692272025

# %%
# 2do par: Expectativa de vida vs 'Mortalidad Infantil'
plt.subplot(1, 2, 2)
sns.scatterplot(data=df_par2_cleaned, x='Infant mortality', y='Life expectancy', alpha=0.6, color='green')
plt.title('Mortalidad Materna vs Espectativa de Vida (Después de la limpieza)')
plt.xlabel('Infant mortality')
plt.ylabel('Life expectancy')

plt.tight_layout()
plt.show()

# %%
correlation_par2_after = df_par2_cleaned.corr().iloc[0, 1]
print(f"Correlación entre 'Infant mortality' y 'Life expectancy' después de la limpieza: {correlation_par2_after}")
# Out:
# Correlación entre 'Infant mortality' y 'Life expectancy' después de la limpieza: -0.9158443765709414

# %% [markdown]
# para ambos casos se observa que los valores estan influenciados por los valores extremos porque se obtuvieron valores en el primer caso de 0,87 antes y de 0,81 despues de la limpieza, para el segundo caso se obtuvieron valores de 0,92 antes y de 0,916 despues de la limpieza, sin embargo se puede concluir que estos valores reflejan una mejor correlación ya que los valores extremos o faltantes han sido ekiminados.

# %% [markdown]
# 5. Realiza lo mismo para comparar la cantidad de médicos por cada mil personas y la
# esperanza de vida. ¿Qué puedes concluir?

# %%
variables = ['Physicians per thousand', 'Life expectancy']
df_medicos_esperanza = df_filtrado[variables].dropna()
df_medicos_esperanza.head()
# Out:
#    Physicians per thousand  Life expectancy
# 0                     0.28             64.5
# 1                     1.20             78.5
# 2                     1.72             76.7
# 4                     0.21             60.8
# 5                     2.76             76.9

# %%
# Datos originales (antes de limpieza)
df_medicos_vida = df_filtrado[variables].dropna()

# Calcular la correlación antes de la limpieza
correlation_before = df_medicos_vida.corr().iloc[0, 1]
print(f"Correlación antes de la limpieza: {correlation_before:.2f}")
# Out:
# Correlación antes de la limpieza: 0.70

# %% [markdown]
# El valor obtenido anteriormente se puede verificar en el mapa de correlaciones

# %%
# Eliminar outliers usando el rango intercuartílico (IQR)
Q1 = df_medicos_vida.quantile(0.25)
Q3 = df_medicos_vida.quantile(0.75)
IQR = Q3 - Q1
df_medicos_vida_cleaned = df_medicos_vida[~((df_medicos_vida < (Q1 - 1.5 * IQR)) |
                                                (df_medicos_vida > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
# Calcular la correlación después de la limpieza
correlation_after = df_medicos_vida_cleaned.corr().iloc[0, 1]
print(f"Correlación después de la limpieza: {correlation_after:.2f}")
# Out:
# Correlación después de la limpieza: 0.74

# %%
# Graficar antes y después de la limpieza
plt.figure(figsize=(12, 6))

# Gráfico antes de la limpieza
plt.subplot(1, 2, 1)
sns.scatterplot(data=df_medicos_vida, x=variables[0], y=variables[1], alpha=0.6)
plt.title('Antes de la limpieza')
plt.xlabel(variables[0])
plt.ylabel(variables[1])

# Gráfico después de la limpieza
plt.subplot(1, 2, 2)
sns.scatterplot(data=df_medicos_vida_cleaned, x=variables[0], y=variables[1], alpha=0.6, color='orange')
plt.title('Después de la limpieza')
plt.xlabel(variables[0])
plt.ylabel(variables[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# El aumento de la correlación de 0.70 a 0.74 después de la limpieza sugiere que los valores atípicos y faltantes estaban afectando ligeramente la relación entre la cantidad de médicos por cada mil personas y la esperanza de vida. Este incremento en la correlación permite realizar algunas conclusiones clave: La correlación de 0.74 indica una relación positiva fuerte: a mayor cantidad de médicos disponibles, mayor es la esperanza de vida. La eliminación de outliers mejoró la precisión del análisis, ya que estos valores extremos probablemente no reflejaban la tendencia general de los datos.

# %% [markdown]
# 6. Construye un gráfico para representar la población total de los países y su producto
# interno bruto. Prepara los datos y escoge el gráfico adecuado (si es necesario, limpia
# y/o transforma los datos). Justifica.

# %%
# Seleccionar las columnas de interés
variables_poblacion_pib = ['Population', 'GDP']
df_poblacion_pib = df_filtrado[variables_poblacion_pib].dropna()

# Limpiar valores atípicos usando IQR
Q1 = df_poblacion_pib.quantile(0.25)
Q3 = df_poblacion_pib.quantile(0.75)
IQR = Q3 - Q1
df_poblacion_pib_cleaned = df_poblacion_pib[~((df_poblacion_pib < (Q1 - 1.5 * IQR)) |
                                              (df_poblacion_pib > (Q3 + 1.5 * IQR))).any(axis=1)]

# Graficar la relación Población vs PIB
plt.figure(figsize=(10, 6))

# Gráfico de dispersión
sns.scatterplot(data=df_poblacion_pib_cleaned, x='Population', y='GDP', alpha=0.7)
plt.title('Relación entre Población y PIB (Datos Limpiados)')
plt.xlabel('Población (millones)')
plt.ylabel('PIB (miles de millones)')
plt.xscale('log')  # Escala logarítmica para población (opcional)
plt.yscale('log')  # Escala logarítmica para PIB (opcional)
plt.grid(True, which="both", linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# Para representar la relación entre la población total y el producto interno bruto, el gráfico de dispersión es ideal, ya que permite visualizar cómo varía el PIB en función de la población. Este enfoque permite explorar si existe una tendencia por ejemplo vemos que países con mayor población tienden a tener un PIB más alto.
